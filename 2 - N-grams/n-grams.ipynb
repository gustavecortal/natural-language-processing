# %% [markdown]
# # Course 2 - N-grams
#
# ## Import librairies

# %%
from datasets import load_dataset
from collections import Counter, defaultdict
import math
from nltk.tokenize import word_tokenize, sent_tokenize

# %% [markdown]
# ## Import dataset

# %%
dataset = load_dataset("gustavecortal/DreamBank-annotated")
df = dataset["train"].to_pandas()
df["report"] = df["report"].astype(str)

train_df = df.query("id != 'vietnam_vet3'")
train_list = list(train_df["report"])
print("Number of dream reports in the training set:",len(train_list))

test_df = df.query("id == 'vietnam_vet3'")
test_list = list(test_df["report"])
print("Number of dream reports in the test set:",len(test_list))
# Out:
# Number of dream reports in the training set: 27489
# Number of dream reports in the test set: 463

# %%
train_strings = " ".join(train_list)
train_strings = train_strings.lower()
train_tokens = word_tokenize(train_strings)
print("Number of tokens in the training set:",len(train_tokens))

vocab = set(train_tokens)
print("Vocabulary size:",len(vocab))

test_strings = " ".join(test_list)
test_strings = test_strings.lower()
test_tokens = word_tokenize(test_strings)
print("Number of tokens in the test set:",len(test_tokens))
# Out:
# Number of tokens in the training set: 5538015
# Vocabulary size: 52195
# Number of tokens in the test set: 78254

# %% [markdown]
# ## Train n-grams

# %%
def tokenize(text):
    """Tokenize the input text."""
    
    return word_tokenize(text)

def count_ngrams(tokens, n):
    """Counts n-grams."""
    
    ngrams = [tuple(tokens[i:i+n]) for i in range(len(tokens)-n+1)]
    
    return Counter(ngrams)

def calculate_ngram_probabilities(train_tokens, n, test_tokens, k=0.00001):
    """Calculates n-gram probabilities."""
    
    vocab = set(train_tokens)
    V = len(vocab)
    ngram_counts = count_ngrams(train_tokens, n)
    n_minus_one_gram_counts = count_ngrams(train_tokens, n-1)
    ngram_probabilities = defaultdict(float)
    
    for ngram in ngram_counts:
        prefix = ngram[:-1]
        ngram_counts[ngram] += k
        n_minus_one_gram_counts[prefix] += k
        ngram_probabilities[ngram] = (ngram_counts[ngram] + k) / (n_minus_one_gram_counts[prefix] + k*V)

    for i in range(len(test_tokens)-n+1):
        ngram = tuple(test_tokens[i:i+n])
        if ngram not in ngram_counts:
            ngram_counts[ngram] = k
            prefix = ngram[:-1]
            if prefix not in n_minus_one_gram_counts:
                n_minus_one_gram_counts[prefix] = k
            ngram_probabilities[ngram] = (ngram_counts[ngram] + k) / (n_minus_one_gram_counts[prefix] + k*V)
    
    return ngram_probabilities

# %% [markdown]
# ## Example

# %%
n = 5

ngram_probabilities = calculate_ngram_probabilities(train_tokens, n, test_tokens)
print(f"Number of {n}-grams:",len(ngram_probabilities))
# Out:
# Number of 5-grams: 4864073

# %%
ngram_probabilities
# Out:
# defaultdict(float,
#             {('the', 'one', 'at', 'the', 'meads'): 0.1329467319687954,
#              ('one', 'at', 'the', 'meads', "'s"): 0.6570606323425058,
#              ('at', 'the', 'meads', "'s", 'house'): 0.6570606323425058,
#              ('the', 'meads', "'s", 'house', ','): 0.6570606323425058,
#              ('meads', "'s", 'house', ',', 'where'): 0.6570606323425058,
#              ("'s", 'house', ',', 'where', 'it'): 0.1050224953686006,
#              ('house', ',', 'where', 'it', "'s"): 0.6570606323425058,
#              (',', 'where', 'it', "'s", 'bigger'): 0.11734624429121941,
#              ('where', 'it', "'s", 'bigger', 'inside'): 0.6570606323425058,
#              ('it', "'s", 'bigger', 'inside', 'than'): 0.6570606323425058,
#              ("'s", 'bigger', 'inside', 'than', 'out'): 0.6570606323425058,
#              ('bigger', 'inside', 'than', 'out', ';'): 0.6570606323425058,
#              ('inside', 'than', 'out', ';', 'there'): 0.6570606323425058,
#              ('than', 'out', ';', 'there', "'s"): 0.6570606323425058,
#              ('out', ';', 'there', "'s", 'a'): 0.6570606323425058,
#              (';', 'there', "'s", 'a', 'european'): 0.39652492505828807,
#              ('there', "'s", 'a', 'european', 'village'): 0.6570606323425058,
#              ("'s", 'a', 'european', 'village', 'just'): 0.6570606323425058,
#              ('a',
#               'european',
#               'village',
#               'just',
#               'inside'): 0.6570606323425058,
#              ('european',
#               'village',
#               'just',
#               'inside',
#               ','): 0.6570606323425058,
#              ('village', 'just', 'inside', ',', 'with'): 0.6570606323425058,
#              ('just', 'inside', ',', 'with', 'a'): 0.6570606323425058,
#              ('inside', ',', 'with', 'a', 'cobblestone'): 0.28393848879601136,
#              (',', 'with', 'a', 'cobblestone', 'street'): 0.6570606323425058,
#              ('with', 'a', 'cobblestone', 'street', 'and'): 0.6570606323425058,
#              ('a', 'cobblestone', 'street', 'and', 'a'): 0.6570606323425058,
#              ('cobblestone',
#               'street',
#               'and',
#               'a',
#               'pied-piper'): 0.6570606323425058,
#              ('street', 'and', 'a', 'pied-piper', 'sort'): 0.6570606323425058,
#              ('and', 'a', 'pied-piper', 'sort', 'of'): 0.6570606323425058,
#              ('a', 'pied-piper', 'sort', 'of', 'man'): 0.6570606323425058,
#              ('pied-piper', 'sort', 'of', 'man', 'with'): 0.6570606323425058,
#              ('sort', 'of', 'man', 'with', 'curly'): 0.6570606323425058,
#              ('of', 'man', 'with', 'curly', 'hair'): 0.6570606323425058,
#              ('man', 'with', 'curly', 'hair', ','): 0.6570606323425058,
#              ('with', 'curly', 'hair', ',', 'he'): 0.39652492505828807,
#              ('curly', 'hair', ',', 'he', 'can'): 0.6570606323425058,
#              ('hair', ',', 'he', 'can', 'do'): 0.6570606323425058,
#              (',', 'he', 'can', 'do', 'things'): 0.6570606323425058,
#              ('he', 'can', 'do', 'things', 'like'): 0.39652492505828807,
#              ('can', 'do', 'things', 'like', 'juggle'): 0.6570606323425058,
#              ('do', 'things', 'like', 'juggle', '-'): 0.6570606323425058,
#              ('things', 'like', 'juggle', '-', 'i'): 0.6570606323425058,
#              ('like', 'juggle', '-', 'i', 'go'): 0.6570606323425058,
#              ('juggle', '-', 'i', 'go', 'up'): 0.6570606323425058,
#              ('-', 'i', 'go', 'up', 'the'): 0.6570606323425058,
#              ('i', 'go', 'up', 'the', 'back'): 0.19008055533379714,
#              ('go', 'up', 'the', 'back', 'stairs'): 0.44229051119426094,
#              ('up', 'the', 'back', 'stairs', '['): 0.39652492505828807,
#              ('the', 'back', 'stairs', '[', 'there'): 0.6570606323425058,
#              ('back', 'stairs', '[', 'there', 'are'): 0.6570606323425058,
#              ('stairs', '[', 'there', 'are', "n't"): 0.6570606323425058,
#              ('[', 'there', 'are', "n't", 'any'): 0.6570606323425058,
#              ('there', 'are', "n't", 'any', 'in'): 0.08679252488291923,
#              ('are', "n't", 'any', 'in', 'the'): 0.6570606323425058,
#              ("n't", 'any', 'in', 'the', 'real'): 0.39652492505828807,
#              ('any', 'in', 'the', 'real', 'house'): 0.6570606323425058,
#              ('in', 'the', 'real', 'house', ']'): 0.39652492505828807,
#              ('the', 'real', 'house', ']', 'and'): 0.6570606323425058,
#              ('real', 'house', ']', 'and', 'then'): 0.6570606323425058,
#              ('house', ']', 'and', 'then', 'down'): 0.6570606323425058,
#              (']', 'and', 'then', 'down', 'the'): 0.6570606323425058,
#              ('and', 'then', 'down', 'the', 'other'): 0.39652492505828807,
#              ('then', 'down', 'the', 'other', 'side'): 0.6570606323425058,
#              ('down', 'the', 'other', 'side', '['): 0.15333120718311674,
#              ('the', 'other', 'side', '[', 'since'): 0.6570606323425058,
#              ('other', 'side', '[', 'since', 'there'): 0.6570606323425058,
#              ('side', '[', 'since', 'there', "'s"): 0.6570606323425058,
#              ('[', 'since', 'there', "'s", 'a'): 0.6570606323425058,
#              ('since', 'there', "'s", 'a', 'second'): 0.6570606323425058,
#              ('there', "'s", 'a', 'second', 'set'): 0.6570606323425058,
#              ("'s", 'a', 'second', 'set', ','): 0.6570606323425058,
#              ('a', 'second', 'set', ',', 'immediately'): 0.6570606323425058,
#              ('second', 'set', ',', 'immediately', ']'): 0.6570606323425058,
#              ('set', ',', 'immediately', ']', 'then'): 0.6570606323425058,
#              (',', 'immediately', ']', 'then', 'down'): 0.6570606323425058,
#              ('immediately', ']', 'then', 'down', 'a'): 0.6570606323425058,
#              (']', 'then', 'down', 'a', 'short'): 0.6570606323425058,
#              ('then', 'down', 'a', 'short', 'empty'): 0.6570606323425058,
#              ('down', 'a', 'short', 'empty', 'hallway'): 0.6570606323425058,
#              ('a', 'short', 'empty', 'hallway', 'that'): 0.6570606323425058,
#              ('short',
#               'empty',
#               'hallway',
#               'that',
#               'turns'): 0.6570606323425058,
#              ('empty', 'hallway', 'that', 'turns', 'a'): 0.6570606323425058,
#              ('hallway', 'that', 'turns', 'a', 'corner'): 0.6570606323425058,
#              ('that', 'turns', 'a', 'corner', ','): 0.6570606323425058,
#              ('turns', 'a', 'corner', ',', 'where'): 0.6570606323425058,
#              ('a', 'corner', ',', 'where', 'i'): 0.5678712989358199,
#              ('corner', ',', 'where', 'i', 'find'): 0.39652492505828807,
#              (',', 'where', 'i', 'find', 'a'): 0.22114746702757215,
#              ('where', 'i', 'find', 'a', 'tiny'): 0.22114746702757215,
#              ('i', 'find', 'a', 'tiny', 'room'): 0.36219385870234483,
#              ('find', 'a', 'tiny', 'room', '...'): 0.39652492505828807,
#              ('a', 'tiny', 'room', '...', 'a'): 0.6570606323425058,
#              ('tiny', 'room', '...', 'a', 'young'): 0.6570606323425058,
#              ('room', '...', 'a', 'young', 'woman'): 0.6570606323425058,
#              ('...', 'a', 'young', 'woman', 'with'): 0.6570606323425058,
#              ('a',
#               'young',
#               'woman',
#               'with',
#               'shoulder-length'): 0.08679252488291923,
#              ('young',
#               'woman',
#               'with',
#               'shoulder-length',
#               'blonde'): 0.6570606323425058,
#              ('woman',
#               'with',
#               'shoulder-length',
#               'blonde',
#               'hair'): 0.6570606323425058,
#              ('with',
#               'shoulder-length',
#               'blonde',
#               'hair',
#               'in'): 0.39652492505828807,
#              ('shoulder-length',
#               'blonde',
#               'hair',
#               'in',
#               'a'): 0.6570606323425058,
#              ('blonde', 'hair', 'in', 'a', 'pageboy'): 0.22114746702757215,
#              ('hair', 'in', 'a', 'pageboy', 'is'): 0.6570606323425058,
#              ('in', 'a', 'pageboy', 'is', 'there'): 0.6570606323425058,
#              ('a', 'pageboy', 'is', 'there', ','): 0.6570606323425058,
#              ('pageboy', 'is', 'there', ',', 'cooking'): 0.6570606323425058,
#              ('is', 'there', ',', 'cooking', 'at'): 0.39652492505828807,
#              ('there', ',', 'cooking', 'at', 'a'): 0.6570606323425058,
#              (',', 'cooking', 'at', 'a', 'stove'): 0.6570606323425058,
#              ('cooking', 'at', 'a', 'stove', 'that'): 0.6570606323425058,
#              ('at', 'a', 'stove', 'that', 'almost'): 0.6570606323425058,
#              ('a', 'stove', 'that', 'almost', 'fills'): 0.6570606323425058,
#              ('stove', 'that', 'almost', 'fills', 'the'): 0.6570606323425058,
#              ('that', 'almost', 'fills', 'the', 'room'): 0.6570606323425058,
#              ('almost', 'fills', 'the', 'room', '...'): 0.6570606323425058,
#              ('fills', 'the', 'room', '...', 'she'): 0.6570606323425058,
#              ('the', 'room', '...', 'she', "'s"): 0.6570606323425058,
#              ('room', '...', 'she', "'s", 'nice'): 0.6570606323425058,
#              ('...', 'she', "'s", 'nice', 'to'): 0.6570606323425058,
#              ('she', "'s", 'nice', 'to', 'me'): 0.6570606323425058,
#              ("'s", 'nice', 'to', 'me', '.'): 0.6570606323425058,
#              ('nice', 'to', 'me', '.', 'now'): 0.07395525500741018,
#              ('to', 'me', '.', 'now', 'outside'): 0.18109874030235643,
#              ('me', '.', 'now', 'outside', ','): 0.6570606323425058,
#              ('.', 'now', 'outside', ',', 'i'): 0.6570606323425058,
#              ('now', 'outside', ',', 'i', "'m"): 0.6570606323425058,
#              ('outside', ',', 'i', "'m", 'waiting'): 0.28393848879601136,
#              (',', 'i', "'m", 'waiting', 'for'): 0.39652492505828807,
#              ('i', "'m", 'waiting', 'for', 'my'): 0.23509244587798112,
#              ("'m", 'waiting', 'for', 'my', 'aunt'): 0.15333120718311674,
#              ('waiting', 'for', 'my', 'aunt', 'to'): 0.6570606323425058,
#              ('for', 'my', 'aunt', 'to', 'pick'): 0.6570606323425058,
#              ('my', 'aunt', 'to', 'pick', 'me'): 0.6570606323425058,
#              ('aunt', 'to', 'pick', 'me', 'up'): 0.6570606323425058,
#              ('to', 'pick', 'me', 'up', '-'): 0.012899828642103477,
#              ('pick', 'me', 'up', '-', 'she'): 0.6570606323425058,
#              ('me', 'up', '-', 'she', 'arrives'): 0.6570606323425058,
#              ('up', '-', 'she', 'arrives', 'in'): 0.6570606323425058,
#              ('-', 'she', 'arrives', 'in', 'a'): 0.6570606323425058,
#              ('she', 'arrives', 'in', 'a', 'little'): 0.6570606323425058,
#              ('arrives', 'in', 'a', 'little', 'round'): 0.6570606323425058,
#              ('in', 'a', 'little', 'round', 'convertible'): 0.6570606323425058,
#              ('a',
#               'little',
#               'round',
#               'convertible',
#               'and'): 0.6570606323425058,
#              ('little',
#               'round',
#               'convertible',
#               'and',
#               'we'): 0.6570606323425058,
#              ('round', 'convertible', 'and', 'we', 'go'): 0.6570606323425058,
#              ('convertible', 'and', 'we', 'go', 'for'): 0.6570606323425058,
#              ('and', 'we', 'go', 'for', 'a'): 0.8845765995276383,
#              ('we', 'go', 'for', 'a', 'drive'): 0.22186280687119325,
#              ('go', 'for', 'a', 'drive', ','): 0.11734624429121941,
#              ('for', 'a', 'drive', ',', 'not'): 0.22114746702757215,
#              ('a', 'drive', ',', 'not', 'very'): 0.6570606323425058,
#              ('drive', ',', 'not', 'very', 'far'): 0.6570606323425058,
#              (',', 'not', 'very', 'far', '-'): 0.28393848879601136,
#              ('not', 'very', 'far', '-', 'we'): 0.6570606323425058,
#              ('very', 'far', '-', 'we', 'cross'): 0.6570606323425058,
#              ('far', '-', 'we', 'cross', 'a'): 0.6570606323425058,
#              ('-', 'we', 'cross', 'a', 'little'): 0.6570606323425058,
#              ('we', 'cross', 'a', 'little', 'bridge'): 0.7930419197766817,
#              ('cross', 'a', 'little', 'bridge', 'over'): 0.39652492505828807,
#              ('a', 'little', 'bridge', 'over', 'a'): 0.6570606323425058,
#              ('little', 'bridge', 'over', 'a', 'creek'): 0.6570606323425058,
#              ('bridge', 'over', 'a', 'creek', ','): 0.6570606323425058,
#              ('over', 'a', 'creek', ',', 'then'): 0.6570606323425058,
#              ('a', 'creek', ',', 'then', 'double'): 0.6570606323425058,
#              ('creek', ',', 'then', 'double', 'back'): 0.6570606323425058,
#              (',', 'then', 'double', 'back', 'and'): 0.6570606323425058,
#              ('then', 'double', 'back', 'and', 'she'): 0.6570606323425058,
#              ('double', 'back', 'and', 'she', 'drops'): 0.6570606323425058,
#              ('back', 'and', 'she', 'drops', 'me'): 0.6570606323425058,
#              ('and', 'she', 'drops', 'me', 'off'): 0.6570606323425058,
#              ('she', 'drops', 'me', 'off', 'at'): 0.6570606323425058,
#              ('drops', 'me', 'off', 'at', 'the'): 0.7930419197766817,
#              ('me', 'off', 'at', 'the', 'house'): 0.22114746702757215,
#              ('off', 'at', 'the', 'house', 'again'): 0.6570606323425058,
#              ('at', 'the', 'house', 'again', '.'): 0.6570606323425058,
#              ('the', 'house', 'again', '.', 'inside'): 0.22114746702757215,
#              ('house', 'again', '.', 'inside', '('): 0.6570606323425058,
#              ('again', '.', 'inside', '(', '?'): 0.6570606323425058,
#              ('.', 'inside', '(', '?', ')'): 0.6570606323425058,
#              ('inside', '(', '?', ')', 'i'): 0.6570606323425058,
#              ('(', '?', ')', 'i', 'sit'): 0.18109874030235643,
#              ('?', ')', 'i', 'sit', 'with'): 0.6570606323425058,
#              (')', 'i', 'sit', 'with', 'a'): 0.6570606323425058,
#              ('i', 'sit', 'with', 'a', 'couple'): 0.1329467319687954,
#              ('sit', 'with', 'a', 'couple', 'of'): 0.6570606323425058,
#              ('with', 'a', 'couple', 'of', 'people'): 0.045954272280016806,
#              ('a', 'couple', 'of', 'people', ','): 0.11932536164353157,
#              ('couple', 'of', 'people', ',', 'playing'): 0.22114746702757215,
#              ('of', 'people', ',', 'playing', 'with'): 0.6570606323425058,
#              ('people', ',', 'playing', 'with', 'a'): 0.6570606323425058,
#              (',', 'playing', 'with', 'a', 'string'): 0.39652492505828807,
#              ('playing', 'with', 'a', 'string', 'of'): 0.6570606323425058,
#              ('with', 'a', 'string', 'of', 'blue'): 0.6570606323425058,
#              ('a', 'string', 'of', 'blue', 'balloons'): 0.6570606323425058,
#              ('string', 'of', 'blue', 'balloons', '.'): 0.6570606323425058,
#              ('of', 'blue', 'balloons', '.', 'i'): 0.6570606323425058,
#              ('blue', 'balloons', '.', 'i', "'m"): 0.6570606323425058,
#              ('balloons', '.', 'i', "'m", 'at'): 0.6570606323425058,
#              ('.', 'i', "'m", 'at', 'a'): 0.35154063497208077,
#              ('i', "'m", 'at', 'a', 'family'): 0.019948039606235642,
#              ("'m", 'at', 'a', 'family', 'reunion'): 0.22114746702757215,
#              ('at', 'a', 'family', 'reunion', 'in'): 0.22114746702757215,
#              ('a', 'family', 'reunion', 'in', 'a'): 0.6570606323425058,
#              ('family', 'reunion', 'in', 'a', 'large'): 0.39652492505828807,
#              ('reunion', 'in', 'a', 'large', 'fine'): 0.6570606323425058,
#              ('in', 'a', 'large', 'fine', 'house'): 0.6570606323425058,
#              ('a', 'large', 'fine', 'house', 'with'): 0.6570606323425058,
#              ('large', 'fine', 'house', 'with', 'grounds'): 0.6570606323425058,
#              ('fine', 'house', 'with', 'grounds', '('): 0.6570606323425058,
#              ('house', 'with', 'grounds', '(', 'or'): 0.6570606323425058,
#              ('with', 'grounds', '(', 'or', 'a'): 0.6570606323425058,
#              ('grounds', '(', 'or', 'a', 'maybe'): 0.6570606323425058,
#              ('(', 'or', 'a', 'maybe', 'a'): 0.6570606323425058,
#              ('or', 'a', 'maybe', 'a', 'rented'): 0.6570606323425058,
#              ('a', 'maybe', 'a', 'rented', 'public'): 0.6570606323425058,
#              ('maybe',
#               'a',
#               'rented',
#               'public',
#               'building'): 0.6570606323425058,
#              ('a', 'rented', 'public', 'building', 'like'): 0.6570606323425058,
#              ('rented',
#               'public',
#               'building',
#               'like',
#               'in'): 0.6570606323425058,
#              ('public', 'building', 'like', 'in', 'a'): 0.6570606323425058,
#              ('building', 'like', 'in', 'a', 'park'): 0.6570606323425058,
#              ('like', 'in', 'a', 'park', ')'): 0.6570606323425058,
#              ('in', 'a', 'park', ')', '-'): 0.6570606323425058,
#              ('a', 'park', ')', '-', 'maybe'): 0.6570606323425058,
#              ('park', ')', '-', 'maybe', 'it'): 0.6570606323425058,
#              (')', '-', 'maybe', 'it', "'s"): 0.6570606323425058,
#              ('-', 'maybe', 'it', "'s", 'granite'): 0.28393848879601136,
#              ('maybe', 'it', "'s", 'granite', 'or'): 0.6570606323425058,
#              ('it', "'s", 'granite', 'or', 'something'): 0.6570606323425058,
#              ("'s", 'granite', 'or', 'something', ','): 0.6570606323425058,
#              ('granite', 'or', 'something', ',', 'very'): 0.6570606323425058,
#              ('or', 'something', ',', 'very', 'imposing'): 0.18109874030235643,
#              ('something', ',', 'very', 'imposing', '.'): 0.6570606323425058,
#              (',', 'very', 'imposing', '.', 'i'): 0.6570606323425058,
#              ('very', 'imposing', '.', 'i', "'m"): 0.6570606323425058,
#              ('imposing', '.', 'i', "'m", 'on'): 0.6570606323425058,
#              ('.', 'i', "'m", 'on', 'a'): 0.4306227936486813,
#              ('i', "'m", 'on', 'a', 'little'): 0.025393411813819478,
#              ("'m", 'on', 'a', 'little', 'round'): 0.22114746702757215,
#              ('on', 'a', 'little', 'round', 'balcony'): 0.39652492505828807,
#              ('a', 'little', 'round', 'balcony', 'with'): 0.6570606323425058,
#              ('little', 'round', 'balcony', 'with', 'a'): 0.6570606323425058,
#              ('round', 'balcony', 'with', 'a', 'few'): 0.6570606323425058,
#              ('balcony', 'with', 'a', 'few', 'others'): 0.6570606323425058,
#              ('with', 'a', 'few', 'others', '('): 0.15333120718311674,
#              ('a', 'few', 'others', '(', 'i'): 0.5678712989358199,
#              ('few', 'others', '(', 'i', 'think'): 0.39652492505828807,
#              ('others', '(', 'i', 'think', 'men'): 0.6570606323425058,
#              ('(', 'i', 'think', 'men', ')'): 0.6570606323425058,
#              ('i', 'think', 'men', ')', ','): 0.6570606323425058,
#              ('think', 'men', ')', ',', 'there'): 0.6570606323425058,
#              ('men', ')', ',', 'there', 'are'): 0.6570606323425058,
#              (')', ',', 'there', 'are', 'lots'): 0.6570606323425058,
#              (',', 'there', 'are', 'lots', 'more'): 0.1329467319687954,
#              ('there', 'are', 'lots', 'more', 'people'): 0.39652492505828807,
#              ('are', 'lots', 'more', 'people', 'inside'): 0.6570606323425058,
#              ('lots', 'more', 'people', 'inside', '.'): 0.6570606323425058,
#              ('more', 'people', 'inside', '.', 'i'): 0.39652492505828807,
#              ('people', 'inside', '.', 'i', 'feel'): 0.18109874030235643,
#              ('inside', '.', 'i', 'feel', 'faint'): 0.18109874030235643,
#              ('.', 'i', 'feel', 'faint', 'and'): 0.6570606323425058,
#              ('i', 'feel', 'faint', 'and', 'collapse'): 0.6570606323425058,
#              ('feel', 'faint', 'and', 'collapse', '.'): 0.6570606323425058,
#              ('faint', 'and', 'collapse', '.', 'they'): 0.6570606323425058,
#              ('and', 'collapse', '.', 'they', 'see'): 0.6570606323425058,
#              ('collapse', '.', 'they', 'see', 'that'): 0.6570606323425058,
#              ('.', 'they', 'see', 'that', 'i'): 0.6570606323425058,
#              ('they', 'see', 'that', 'i', "'m"): 0.6570606323425058,
#              ('see', 'that', 'i', "'m", 'very'): 0.22114746702757215,
#              ('that', 'i', "'m", 'very', 'sick'): 0.15333120718311674,
#              ('i', "'m", 'very', 'sick', ','): 0.6570606323425058,
#              ("'m", 'very', 'sick', ',', 'and'): 0.6570606323425058,
#              ('very', 'sick', ',', 'and', 'quickly'): 0.6570606323425058,
#              ('sick', ',', 'and', 'quickly', 'take'): 0.6570606323425058,
#              (',', 'and', 'quickly', 'take', 'me'): 0.6570606323425058,
#              ('and', 'quickly', 'take', 'me', 'to'): 0.6570606323425058,
#              ('quickly', 'take', 'me', 'to', 'a'): 0.6570606323425058,
#              ('take', 'me', 'to', 'a', 'car'): 0.23469014170449054,
#              ('me', 'to', 'a', 'car', 'to'): 0.39652492505828807,
#              ('to', 'a', 'car', 'to', 'go'): 0.28393848879601136,
#              ('a', 'car', 'to', 'go', 'to'): 0.5432889771023333,
#              ('car', 'to', 'go', 'to', 'the'): 0.36219385870234483,
#              ('to', 'go', 'to', 'the', 'hospital'): 0.024412176354192044,
#              ('go', 'to', 'the', 'hospital', '.'): 0.12105222382816568,
#              ('to', 'the', 'hospital', '.', '('): 0.029831787878751723,
#              ('the', 'hospital', '.', '(', 'i'): 0.7930419197766817,
#              ('hospital', '.', '(', 'i', 'do'): 0.39652492505828807,
#              ('.', '(', 'i', 'do', "n't"): 0.8436219583020306,
#              ('(', 'i', 'do', "n't", 'see'): 0.00947688992888305,
#              ('i', 'do', "n't", 'see', 'any'): 0.18989776363252098,
#              ('do', "n't", 'see', 'any', 'of'): 0.051225389253947866,
#              ("n't", 'see', 'any', 'of', 'that'): 0.39652492505828807,
#              ('see', 'any', 'of', 'that', ','): 0.6570606323425058,
#              ('any', 'of', 'that', ',', 'the'): 0.22114746702757215,
#              ('of', 'that', ',', 'the', 'next'): 0.28393848879601136,
#              ('that', ',', 'the', 'next', 'i'): 0.6570606323425058,
#              (',', 'the', 'next', 'i', 'know'): 0.39652492505828807,
#              ('the', 'next', 'i', 'know', 'is'): 0.6570606323425058,
#              ('next', 'i', 'know', 'is', 'that'): 0.6570606323425058,
#              ('i', 'know', 'is', 'that', 'i'): 0.5207464702186085,
#              ('know', 'is', 'that', 'i', "'m"): 0.23469014170449054,
#              ('is', 'that', 'i', "'m", 'lying'): 0.05707238231339417,
#              ('that', 'i', "'m", 'lying', 'in'): 0.6570606323425058,
#              ('i', "'m", 'lying', 'in', 'the'): 0.15333120718311674,
#              ("'m", 'lying', 'in', 'the', 'back'): 0.6570606323425058,
#              ('lying', 'in', 'the', 'back', 'seat'): 0.39652492505828807,
#              ('in', 'the', 'back', 'seat', 'of'): 0.2890482153462596,
#              ('the', 'back', 'seat', 'of', 'the'): 0.29894308803339786,
#              ('back', 'seat', 'of', 'the', 'car'): 0.7868327970773443,
#              ('seat', 'of', 'the', 'car', '-'): 0.05399104630395488,
#              ('of', 'the', 'car', '-', 'a'): 0.6570606323425058,
#              ('the', 'car', '-', 'a', 'sedan'): 0.39652492505828807,
#              ('car', '-', 'a', 'sedan', '-'): 0.6570606323425058,
#              ('-', 'a', 'sedan', '-', 'going'): 0.6570606323425058,
#              ('a', 'sedan', '-', 'going', 'like'): 0.6570606323425058,
#              ('sedan',
#               '-',
#               'going',
#               'like',
#               'gangbusters'): 0.6570606323425058,
#              ('-', 'going', 'like', 'gangbusters', 'on'): 0.6570606323425058,
#              ('going', 'like', 'gangbusters', 'on', 'a'): 0.6570606323425058,
#              ('like', 'gangbusters', 'on', 'a', 'huge'): 0.6570606323425058,
#              ('gangbusters', 'on', 'a', 'huge', 'freeway'): 0.6570606323425058,
#              ('on', 'a', 'huge', 'freeway', '.'): 0.6570606323425058,
#              ('a', 'huge', 'freeway', '.', 'it'): 0.6570606323425058,
#              ('huge', 'freeway', '.', 'it', 'must'): 0.6570606323425058,
#              ('freeway', '.', 'it', 'must', 'be'): 0.6570606323425058,
#              ('.', 'it', 'must', 'be', '5'): 0.03918272734539197,
#              ('it', 'must', 'be', '5', 'lanes'): 0.6570606323425058,
#              ('must', 'be', '5', 'lanes', 'in'): 0.6570606323425058,
#              ('be', '5', 'lanes', 'in', 'each'): 0.6570606323425058,
#              ('5', 'lanes', 'in', 'each', 'direction'): 0.6570606323425058,
#              ('lanes', 'in', 'each', 'direction', ','): 0.6570606323425058,
#              ('in', 'each', 'direction', ',', 'lots'): 0.6570606323425058,
#              ('each', 'direction', ',', 'lots', 'of'): 0.6570606323425058,
#              ('direction', ',', 'lots', 'of', 'cars'): 0.6570606323425058,
#              (',', 'lots', 'of', 'cars', 'but'): 0.6570606323425058,
#              ('lots', 'of', 'cars', 'but', 'not'): 0.6570606323425058,
#              ('of', 'cars', 'but', 'not', 'crowded'): 0.6570606323425058,
#              ('cars', 'but', 'not', 'crowded', ','): 0.6570606323425058,
#              ('but', 'not', 'crowded', ',', 'and'): 0.6570606323425058,
#              ('not', 'crowded', ',', 'and', 'all'): 0.6570606323425058,
#              ('crowded', ',', 'and', 'all', 'going'): 0.39652492505828807,
#              (',', 'and', 'all', 'going', 'really'): 0.6570606323425058,
#              ('and', 'all', 'going', 'really', 'fast'): 0.6570606323425058,
#              ('all', 'going', 'really', 'fast', '.'): 0.6570606323425058,
#              ('going', 'really', 'fast', '.', 'i'): 0.8518041090756284,
#              ('really', 'fast', '.', 'i', 'ca'): 0.1050224953686006,
#              ('fast', '.', 'i', 'ca', "n't"): 0.6570606323425058,
#              ('.', 'i', 'ca', "n't", 'see'): 0.053085809850681696,
#              ('i', 'ca', "n't", 'see', 'anything'): 0.0497836244946564,
#              ('ca', "n't", 'see', 'anything', 'else'): 0.14790903093930172,
#              ("n't", 'see', 'anything', 'else', 'but'): 0.39652492505828807,
#              ('see', 'anything', 'else', 'but', 'freeway'): 0.6570606323425058,
#              ('anything', 'else', 'but', 'freeway', 'and'): 0.6570606323425058,
#              ('else', 'but', 'freeway', 'and', 'blue'): 0.6570606323425058,
#              ('but', 'freeway', 'and', 'blue', 'sky'): 0.6570606323425058,
#              ('freeway', 'and', 'blue', 'sky', ','): 0.6570606323425058,
#              ('and', 'blue', 'sky', ',', 'with'): 0.6570606323425058,
#              ('blue', 'sky', ',', 'with', 'a'): 0.6570606323425058,
#              ('sky', ',', 'with', 'a', 'few'): 0.6570606323425058,
#              (',', 'with', 'a', 'few', 'white'): 0.1050224953686006,
#              ('with', 'a', 'few', 'white', 'clouds'): 0.6570606323425058,
#              ('a', 'few', 'white', 'clouds', '.'): 0.6570606323425058,
#              ('few', 'white', 'clouds', '.', 'as'): 0.6570606323425058,
#              ('white', 'clouds', '.', 'as', 'we'): 0.6570606323425058,
#              ('clouds', '.', 'as', 'we', 'barrel'): 0.6570606323425058,
#              ('.', 'as', 'we', 'barrel', 'along'): 0.6570606323425058,
#              ('as', 'we', 'barrel', 'along', ','): 0.6570606323425058,
#              ('we', 'barrel', 'along', ',', 'the'): 0.6570606323425058,
#              ('barrel', 'along', ',', 'the', 'road'): 0.6570606323425058,
#              ('along', ',', 'the', 'road', 'rises'): 0.6570606323425058,
#              (',', 'the', 'road', 'rises', ','): 0.6570606323425058,
#              ('the', 'road', 'rises', ',', 'and'): 0.6570606323425058,
#              ('road', 'rises', ',', 'and', 'quickly'): 0.6570606323425058,
#              ('rises', ',', 'and', 'quickly', '-'): 0.6570606323425058,
#              (',', 'and', 'quickly', '-', 'soon'): 0.6570606323425058,
#              ('and', 'quickly', '-', 'soon', 'it'): 0.6570606323425058,
#              ('quickly', '-', 'soon', 'it', 'changes'): 0.6570606323425058,
#              ('-', 'soon', 'it', 'changes', 'to'): 0.6570606323425058,
#              ('soon', 'it', 'changes', 'to', 'steps'): 0.6570606323425058,
#              ('it', 'changes', 'to', 'steps', ','): 0.6570606323425058,
#              ('changes', 'to', 'steps', ',', 'which'): 0.6570606323425058,
#              ('to', 'steps', ',', 'which', 'does'): 0.6570606323425058,
#              ('steps', ',', 'which', 'does', "n't"): 0.6570606323425058,
#              (',', 'which', 'does', "n't", 'slow'): 0.05707238231339417,
#              ('which', 'does', "n't", 'slow', 'anybody'): 0.6570606323425058,
#              ('does', "n't", 'slow', 'anybody', 'down'): 0.6570606323425058,
#              ("n't", 'slow', 'anybody', 'down', ','): 0.6570606323425058,
#              ('slow', 'anybody', 'down', ',', 'and'): 0.6570606323425058,
#              ('anybody', 'down', ',', 'and', 'it'): 0.6570606323425058,
#              ('down', ',', 'and', 'it', 'keeps'): 0.22114746702757215,
#              (',', 'and', 'it', 'keeps', 'going'): 0.39652492505828807,
#              ('and', 'it', 'keeps', 'going', 'up'): 0.6570606323425058,
#              ('it', 'keeps', 'going', 'up', ','): 0.39652492505828807,
#              ('keeps', 'going', 'up', ',', 'the'): 0.6570606323425058,
#              ('going', 'up', ',', 'the', 'incline'): 0.6570606323425058,
#              ('up', ',', 'the', 'incline', 'increasing'): 0.6570606323425058,
#              (',', 'the', 'incline', 'increasing', '.'): 0.6570606323425058,
#              ('the', 'incline', 'increasing', '.', 'now'): 0.6570606323425058,
#              ('incline', 'increasing', '.', 'now', 'my'): 0.6570606323425058,
#              ('increasing', '.', 'now', 'my', 'line'): 0.6570606323425058,
#              ('.', 'now', 'my', 'line', 'of'): 0.6570606323425058,
#              ('now', 'my', 'line', 'of', 'sight'): 0.6570606323425058,
#              ('my', 'line', 'of', 'sight', 'changes'): 0.39652492505828807,
#              ('line', 'of', 'sight', 'changes', 'to'): 0.6570606323425058,
#              ('of', 'sight', 'changes', 'to', 'a'): 0.6570606323425058,
#              ('sight', 'changes', 'to', 'a', 'spot'): 0.6570606323425058,
#              ('changes', 'to', 'a', 'spot', 'at'): 0.6570606323425058,
#              ('to', 'a', 'spot', 'at', 'the'): 0.6570606323425058,
#              ('a', 'spot', 'at', 'the', 'side'): 0.6570606323425058,
#              ('spot', 'at', 'the', 'side', 'of'): 0.6570606323425058,
#              ('at', 'the', 'side', 'of', 'the'): 0.8971558554047067,
#              ('the', 'side', 'of', 'the', 'freeway'): 0.011816131514776765,
#              ('side', 'of', 'the', 'freeway', '('): 0.11734624429121941,
#              ('of', 'the', 'freeway', '(', 'outside'): 0.39652492505828807,
#              ('the', 'freeway', '(', 'outside', 'of'): 0.6570606323425058,
#              ('freeway', '(', 'outside', 'of', 'the'): 0.6570606323425058,
#              ('(', 'outside', 'of', 'the', 'car'): 0.6570606323425058,
#              ('outside', 'of', 'the', 'car', ')'): 0.18109874030235643,
#              ('of', 'the', 'car', ')', ','): 0.39652492505828807,
#              ('the', 'car', ')', ',', 'looking'): 0.39652492505828807,
#              ('car', ')', ',', 'looking', 'across'): 0.6570606323425058,
#              (')', ',', 'looking', 'across', 'it'): 0.6570606323425058,
#              (',', 'looking', 'across', 'it', '-'): 0.6570606323425058,
#              ('looking', 'across', 'it', '-', 'and'): 0.6570606323425058,
#              ('across', 'it', '-', 'and', 'the'): 0.6570606323425058,
#              ('it', '-', 'and', 'the', 'incline'): 0.28393848879601136,
#              ('-', 'and', 'the', 'incline', '('): 0.6570606323425058,
#              ('and', 'the', 'incline', '(', 'without'): 0.6570606323425058,
#              ('the', 'incline', '(', 'without', 'the'): 0.6570606323425058,
#              ('incline', '(', 'without', 'the', 'steps'): 0.6570606323425058,
#              ('(', 'without', 'the', 'steps', ')'): 0.7930419197766817,
#              ('without', 'the', 'steps', ')', 'takes'): 0.39652492505828807,
#              ('the', 'steps', ')', 'takes', 'a'): 0.6570606323425058,
#              ('steps', ')', 'takes', 'a', 'sharp'): 0.6570606323425058,
#              (')', 'takes', 'a', 'sharp', 'turn'): 0.6570606323425058,
#              ('takes', 'a', 'sharp', 'turn', 'up'): 0.6570606323425058,
#              ('a', 'sharp', 'turn', 'up', 'to'): 0.6570606323425058,
#              ('sharp', 'turn', 'up', 'to', 'vertical'): 0.6570606323425058,
#              ('turn', 'up', 'to', 'vertical', '.'): 0.6570606323425058,
#              ('up', 'to', 'vertical', '.', 'the'): 0.6570606323425058,
#              ('to', 'vertical', '.', 'the', 'cars'): 0.6570606323425058,
#              ('vertical', '.', 'the', 'cars', 'are'): 0.6570606323425058,
#              ('.', 'the', 'cars', 'are', 'not'): 0.28393848879601136,
#              ('the', 'cars', 'are', 'not', 'stopping'): 0.6570606323425058,
#              ('cars', 'are', 'not', 'stopping', 'or'): 0.6570606323425058,
#              ('are', 'not', 'stopping', 'or', 'even'): 0.6570606323425058,
#              ('not', 'stopping', 'or', 'even', 'slowing'): 0.6570606323425058,
#              ('stopping', 'or', 'even', 'slowing', 'down'): 0.6570606323425058,
#              ('or', 'even', 'slowing', 'down', ','): 0.6570606323425058,
#              ('even', 'slowing', 'down', ',', 'and'): 0.6570606323425058,
#              ('slowing', 'down', ',', 'and', 'they'): 0.6570606323425058,
#              ('down', ',', 'and', 'they', 'whoosh'): 0.28393848879601136,
#              (',', 'and', 'they', 'whoosh', 'straight'): 0.6570606323425058,
#              ('and', 'they', 'whoosh', 'straight', 'up'): 0.6570606323425058,
#              ('they', 'whoosh', 'straight', 'up', '.'): 0.6570606323425058,
#              ('whoosh', 'straight', 'up', '.', 'they'): 0.6570606323425058,
#              ('straight', 'up', '.', 'they', 'make'): 0.6570606323425058,
#              ('up', '.', 'they', 'make', 'it'): 0.6570606323425058,
#              ('.', 'they', 'make', 'it', 'about'): 0.6570606323425058,
#              ('they', 'make', 'it', 'about', 'halfway'): 0.6570606323425058,
#              ('make', 'it', 'about', 'halfway', 'up'): 0.6570606323425058,
#              ('it', 'about', 'halfway', 'up', 'on'): 0.6570606323425058,
#              ('about', 'halfway', 'up', 'on', 'momentum'): 0.6570606323425058,
#              ('halfway', 'up', 'on', 'momentum', ','): 0.6570606323425058,
#              ('up', 'on', 'momentum', ',', 'and'): 0.6570606323425058,
#              ('on', 'momentum', ',', 'and', 'then'): 0.6570606323425058,
#              ('momentum', ',', 'and', 'then', 'gravity'): 0.6570606323425058,
#              (',', 'and', 'then', 'gravity', 'takes'): 0.6570606323425058,
#              ('and', 'then', 'gravity', 'takes', 'over'): 0.6570606323425058,
#              ('then', 'gravity', 'takes', 'over', 'and'): 0.6570606323425058,
#              ('gravity', 'takes', 'over', 'and', 'they'): 0.6570606323425058,
#              ('takes', 'over', 'and', 'they', 'fall'): 0.6570606323425058,
#              ('over', 'and', 'they', 'fall', 'down'): 0.6570606323425058,
#              ('and', 'they', 'fall', 'down', '.'): 0.6570606323425058,
#              ('they', 'fall', 'down', '.', 'i'): 0.6570606323425058,
#              ('fall', 'down', '.', 'i', 'can'): 0.28393848879601136,
#              ('down', '.', 'i', 'can', 'see'): 0.6570606323425058,
#              ('.', 'i', 'can', 'see', 'them'): 0.024533512197204288,
#              ('i', 'can', 'see', 'them', 'sort'): 0.1050224953686006,
#              ('can', 'see', 'them', 'sort', 'of'): 0.6570606323425058,
#              ('see', 'them', 'sort', 'of', 'drop'): 0.6570606323425058,
#              ('them', 'sort', 'of', 'drop', 'off'): 0.6570606323425058,
#              ('sort', 'of', 'drop', 'off', '['): 0.6570606323425058,
#              ('of', 'drop', 'off', '[', 'rather'): 0.6570606323425058,
#              ('drop', 'off', '[', 'rather', 'than'): 0.6570606323425058,
#              ('off', '[', 'rather', 'than', 'sliding'): 0.6570606323425058,
#              ('[', 'rather', 'than', 'sliding', 'down'): 0.6570606323425058,
#              ('rather',
#               'than',
#               'sliding',
#               'down',
#               'still'): 0.6570606323425058,
#              ('than', 'sliding', 'down', 'still', 'in'): 0.6570606323425058,
#              ('sliding', 'down', 'still', 'in', 'contact'): 0.6570606323425058,
#              ('down', 'still', 'in', 'contact', 'with'): 0.6570606323425058,
#              ('still', 'in', 'contact', 'with', 'the'): 0.6570606323425058,
#              ('in', 'contact', 'with', 'the', 'pavement'): 0.22114746702757215,
#              ('contact', 'with', 'the', 'pavement', ']'): 0.6570606323425058,
#              ('with', 'the', 'pavement', ']', 'and'): 0.6570606323425058,
#              ('the', 'pavement', ']', 'and', 'fall'): 0.6570606323425058,
#              ('pavement', ']', 'and', 'fall', 'down'): 0.6570606323425058,
#              (']', 'and', 'fall', 'down', 'way'): 0.6570606323425058,
#              ('and', 'fall', 'down', 'way', 'below'): 0.6570606323425058,
#              ('fall', 'down', 'way', 'below', 'me'): 0.6570606323425058,
#              ('down', 'way', 'below', 'me', '.'): 0.6570606323425058,
#              ('way', 'below', 'me', '.', 'i'): 0.6570606323425058,
#              ('below', 'me', '.', 'i', 'watch'): 0.22114746702757215,
#              ('me', '.', 'i', 'watch', 'a'): 0.1329467319687954,
#              ('.', 'i', 'watch', 'a', 'plane'): 0.1050224953686006,
#              ('i', 'watch', 'a', 'plane', 'fly'): 0.6570606323425058,
#              ('watch', 'a', 'plane', 'fly', 'past'): 0.6570606323425058,
#              ('a', 'plane', 'fly', 'past', 'and'): 0.6570606323425058,
#              ('plane', 'fly', 'past', 'and', 'shortly'): 0.6570606323425058,
#              ('fly', 'past', 'and', 'shortly', 'realize'): 0.6570606323425058,
#              ('past', 'and', 'shortly', 'realize', 'it'): 0.6570606323425058,
#              ('and', 'shortly', 'realize', 'it', 'was'): 0.6570606323425058,
#              ('shortly', 'realize', 'it', 'was', 'too'): 0.6570606323425058,
#              ('realize', 'it', 'was', 'too', 'low'): 0.6570606323425058,
#              ('it', 'was', 'too', 'low', '.'): 0.28393848879601136,
#              ('was', 'too', 'low', '.', 'it'): 0.39652492505828807,
#              ('too', 'low', '.', 'it', 'crashes'): 0.6570606323425058,
#              ('low', '.', 'it', 'crashes', 'not'): 0.6570606323425058,
#              ('.', 'it', 'crashes', 'not', 'half'): 0.6570606323425058,
#              ('it', 'crashes', 'not', 'half', 'a'): 0.6570606323425058,
#              ('crashes', 'not', 'half', 'a', 'block'): 0.6570606323425058,
#              ('not', 'half', 'a', 'block', 'away'): 0.6570606323425058,
#              ('half', 'a', 'block', 'away', '('): 0.39652492505828807,
#              ('a', 'block', 'away', '(', 'rather'): 0.6570606323425058,
#              ('block', 'away', '(', 'rather', 'as'): 0.6570606323425058,
#              ('away', '(', 'rather', 'as', 'though'): 0.6570606323425058,
#              ('(', 'rather', 'as', 'though', 'it'): 0.6570606323425058,
#              ('rather', 'as', 'though', 'it', 'fell'): 0.6570606323425058,
#              ('as', 'though', 'it', 'fell', 'from'): 0.6570606323425058,
#              ('though', 'it', 'fell', 'from', 'a'): 0.6570606323425058,
#              ('it', 'fell', 'from', 'a', 'height'): 0.6570606323425058,
#              ('fell', 'from', 'a', 'height', 'of'): 0.6570606323425058,
#              ('from', 'a', 'height', 'of', 'a'): 0.6570606323425058,
#              ('a', 'height', 'of', 'a', 'few'): 0.6570606323425058,
#              ('height', 'of', 'a', 'few', 'yards'): 0.6570606323425058,
#              ('of', 'a', 'few', 'yards', 'than'): 0.6570606323425058,
#              ('a', 'few', 'yards', 'than', 'flying'): 0.6570606323425058,
#              ('few',
#               'yards',
#               'than',
#               'flying',
#               'straight'): 0.6570606323425058,
#              ('yards',
#               'than',
#               'flying',
#               'straight',
#               'into'): 0.6570606323425058,
#              ('than', 'flying', 'straight', 'into', 'the'): 0.6570606323425058,
#              ('flying',
#               'straight',
#               'into',
#               'the',
#               'ground'): 0.6570606323425058,
#              ('straight', 'into', 'the', 'ground', ')'): 0.6570606323425058,
#              ('into', 'the', 'ground', ')', '.'): 0.6570606323425058,
#              ('the', 'ground', ')', '.', 'and'): 0.39652492505828807,
#              ('ground', ')', '.', 'and', 'i'): 0.6570606323425058,
#              (')', '.', 'and', 'i', 'think'): 0.28393848879601136,
#              ('.', 'and', 'i', 'think', 'there'): 0.07723883120400651,
#              ('and', 'i', 'think', 'there', 'might'): 0.03770535812587004,
#              ('i', 'think', 'there', 'might', 'be'): 0.6570606323425058,
#              ('think',
#               'there',
#               'might',
#               'be',
#               'survivors'): 0.39652492505828807,
#              ('there', 'might', 'be', 'survivors', ','): 0.6570606323425058,
#              ('might', 'be', 'survivors', ',', 'and'): 0.6570606323425058,
#              ('be', 'survivors', ',', 'and', 'that'): 0.6570606323425058,
#              ('survivors', ',', 'and', 'that', 'i'): 0.6570606323425058,
#              (',', 'and', 'that', 'i', 'should'): 0.07105035263204262,
#              ('and', 'that', 'i', 'should', 'call'): 0.048729263676568914,
#              ('that', 'i', 'should', 'call', 'the'): 0.18109874030235643,
#              ('i', 'should', 'call', 'the', 'police'): 0.44229051119426094,
#              ('should', 'call', 'the', 'police', '.'): 0.5678712989358199,
#              ('call', 'the', 'police', '.', 'before'): 0.028152162774801846,
#              ('the', 'police', '.', 'before', 'i'): 0.6570606323425058,
#              ('police', '.', 'before', 'i', 'get'): 0.6570606323425058,
#              ('.', 'before', 'i', 'get', 'the'): 0.18109874030235643,
#              ('before', 'i', 'get', 'the', 'number'): 0.39652492505828807,
#              ('i', 'get', 'the', 'number', 'dialed'): 0.22114746702757215,
#              ('get', 'the', 'number', 'dialed', ','): 0.6570606323425058,
#              ('the', 'number', 'dialed', ',', 'i'): 0.6570606323425058,
#              ('number', 'dialed', ',', 'i', 'realize'): 0.6570606323425058,
#              ('dialed', ',', 'i', 'realize', 'i'): 0.6570606323425058,
#              (',', 'i', 'realize', 'i', 'want'): 0.0974575527873556,
#              ('i', 'realize', 'i', 'want', 'the'): 0.36219385870234483,
#              ('realize', 'i', 'want', 'the', 'fire'): 0.39652492505828807,
#              ('i', 'want', 'the', 'fire', 'department'): 0.6570606323425058,
#              ('want',
#               'the',
#               'fire',
#               'department',
#               'instead'): 0.6570606323425058,
#              ('the', 'fire', 'department', 'instead', '.'): 0.6570606323425058,
#              ('fire', 'department', 'instead', '.', 'i'): 0.6570606323425058,
#              ('department', 'instead', '.', 'i', 'get'): 0.6570606323425058,
#              ('instead', '.', 'i', 'get', 'no'): 0.39652492505828807,
#              ('.', 'i', 'get', 'no', 'ring'): 0.39652492505828807,
#              ('i', 'get', 'no', 'ring', ','): 0.6570606323425058,
#              ('get', 'no', 'ring', ',', 'try'): 0.6570606323425058,
#              ('no', 'ring', ',', 'try', 'again'): 0.6570606323425058,
#              ('ring', ',', 'try', 'again', 'and'): 0.6570606323425058,
#              (',', 'try', 'again', 'and', 'find'): 0.6570606323425058,
#              ('try', 'again', 'and', 'find', 'the'): 0.6570606323425058,
#              ('again', 'and', 'find', 'the', 'line'): 0.6570606323425058,
#              ('and', 'find', 'the', 'line', 'is'): 0.39652492505828807,
#              ('find', 'the', 'line', 'is', 'dead'): 0.6570606323425058,
#              ('the', 'line', 'is', 'dead', '.'): 0.39652492505828807,
#              ('line', 'is', 'dead', '.', 'some'): 0.39652492505828807,
#              ('is', 'dead', '.', 'some', 'people'): 0.6570606323425058,
#              ('dead', '.', 'some', 'people', '('): 0.6570606323425058,
#              ('.', 'some', 'people', '(', '3'): 0.6570606323425058,
#              ('some', 'people', '(', '3', '?'): 0.6570606323425058,
#              ('people', '(', '3', '?', '-'): 0.6570606323425058,
#              ('(', '3', '?', '-', 'at'): 0.6570606323425058,
#              ('3', '?', '-', 'at', 'least'): 0.6570606323425058,
#              ('?', '-', 'at', 'least', 'one'): 0.6570606323425058,
#              ('-', 'at', 'least', 'one', 'a'): 0.6570606323425058,
#              ('at', 'least', 'one', 'a', 'woman'): 0.6570606323425058,
#              ('least', 'one', 'a', 'woman', ')'): 0.6570606323425058,
#              ('one', 'a', 'woman', ')', 'are'): 0.6570606323425058,
#              ('a', 'woman', ')', 'are', 'coming'): 0.6570606323425058,
#              ('woman', ')', 'are', 'coming', 'toward'): 0.6570606323425058,
#              (')', 'are', 'coming', 'toward', 'the'): 0.6570606323425058,
#              ('are', 'coming', 'toward', 'the', 'house'): 0.6570606323425058,
#              ('coming', 'toward', 'the', 'house', 'and'): 0.22114746702757215,
#              ('toward', 'the', 'house', 'and', 'i'): 0.28393848879601136,
#              ('the', 'house', 'and', 'i', 'understand'): 0.017385012610835932,
#              ('house', 'and', 'i', 'understand', 'they'): 0.6570606323425058,
#              ('and', 'i', 'understand', 'they', 'are'): 0.6570606323425058,
#              ('i',
#               'understand',
#               'they',
#               'are',
#               'responsible'): 0.6570606323425058,
#              ('understand',
#               'they',
#               'are',
#               'responsible',
#               'for'): 0.6570606323425058,
#              ('they', 'are', 'responsible', 'for', 'the'): 0.6570606323425058,
#              ('are', 'responsible', 'for', 'the', 'dead'): 0.6570606323425058,
#              ('responsible',
#               'for',
#               'the',
#               'dead',
#               'phone'): 0.6570606323425058,
#              ('for', 'the', 'dead', 'phone', 'and'): 0.6570606323425058,
#              ('the', 'dead', 'phone', 'and', 'i'): 0.6570606323425058,
#              ('dead', 'phone', 'and', 'i', 'should'): 0.6570606323425058,
#              ('phone', 'and', 'i', 'should', 'be'): 0.6570606323425058,
#              ('and', 'i', 'should', 'be', 'suspicious'): 0.15333120718311674,
#              ('i', 'should', 'be', 'suspicious', 'of'): 0.6570606323425058,
#              ('should', 'be', 'suspicious', 'of', 'them'): 0.6570606323425058,
#              ('be', 'suspicious', 'of', 'them', '.'): 0.6570606323425058,
#              ('suspicious', 'of', 'them', '.', 'i'): 0.6570606323425058,
#              ('of', 'them', '.', 'i', 'try'): 0.0052765389298422205,
#              ('them', '.', 'i', 'try', 'to'): 0.6388792169915891,
#              ('.', 'i', 'try', 'to', 'leave'): 0.0032335472777716744,
#              ('i', 'try', 'to', 'leave', 'the'): 0.28393848879601136,
#              ('try', 'to', 'leave', 'the', 'house'): 0.39652492505828807,
#              ('to', 'leave', 'the', 'house', '-'): 0.07395525500741018,
#              ('leave', 'the', 'house', '-', 'run'): 0.6570606323425058,
#              ('the', 'house', '-', 'run', 'into'): 0.6570606323425058,
#              ('house', '-', 'run', 'into', 'a'): 0.6570606323425058,
#              ('-', 'run', 'into', 'a', 'pregnant'): 0.6570606323425058,
#              ('run', 'into', 'a', 'pregnant', 'girl'): 0.6570606323425058,
#              ('into', 'a', 'pregnant', 'girl', 'at'): 0.6570606323425058,
#              ('a', 'pregnant', 'girl', 'at', 'the'): 0.6570606323425058,
#              ('pregnant', 'girl', 'at', 'the', 'back'): 0.6570606323425058,
#              ('girl', 'at', 'the', 'back', ';'): 0.39652492505828807,
#              ('at', 'the', 'back', ';', 'she'): 0.6570606323425058,
#              ('the', 'back', ';', 'she', 'seems'): 0.6570606323425058,
#              ('back', ';', 'she', 'seems', 'to'): 0.6570606323425058,
#              (';', 'she', 'seems', 'to', 'be'): 0.28393848879601136,
# ...
#              ('couple', 'of', 'chests', 'of', 'drawers'): 0.6570606323425058,
#              ('of', 'chests', 'of', 'drawers', 'that'): 0.6570606323425058,
#              ('chests', 'of', 'drawers', 'that', 'i'): 0.6570606323425058,
#              ('of', 'drawers', 'that', 'i', 'realize'): 0.6570606323425058,
#              ('drawers', 'that', 'i', 'realize', 'i'): 0.6570606323425058,
#              ('that', 'i', 'realize', 'i', 'could'): 0.6570606323425058,
#              ('i', 'realize', 'i', 'could', 'have'): 0.35203403911776165,
#              ('realize', 'i', 'could', 'have', 'used'): 0.22114746702757215,
#              ('i', 'could', 'have', 'used', 'downstairs'): 0.22114746702757215,
#              ('could',
#               'have',
#               'used',
#               'downstairs',
#               'long'): 0.6570606323425058,
#              ('have', 'used', 'downstairs', 'long', 'ago'): 0.6570606323425058,
#              ('used', 'downstairs', 'long', 'ago', ','): 0.6570606323425058,
#              ('downstairs', 'long', 'ago', ',', 'yet'): 0.6570606323425058,
#              ('long', 'ago', ',', 'yet', 'i'): 0.6570606323425058,
#              ('ago', ',', 'yet', 'i', "'ve"): 0.6570606323425058,
#              (',', 'yet', 'i', "'ve", 'been'): 0.6570606323425058,
#              ('yet', 'i', "'ve", 'been', 'looking'): 0.6570606323425058,
#              ('i', "'ve", 'been', 'looking', 'for'): 0.6634335553609497,
#              ("'ve",
#               'been',
#               'looking',
#               'for',
#               'acceptable'): 0.28393848879601136,
#              ('been',
#               'looking',
#               'for',
#               'acceptable',
#               'furniture'): 0.6570606323425058,
#              ('looking',
#               'for',
#               'acceptable',
#               'furniture',
#               'all'): 0.6570606323425058,
#              ('for',
#               'acceptable',
#               'furniture',
#               'all',
#               'this'): 0.6570606323425058,
#              ('acceptable',
#               'furniture',
#               'all',
#               'this',
#               'time'): 0.6570606323425058,
#              ('furniture', 'all', 'this', 'time', '.'): 0.6570606323425058,
#              ('all', 'this', 'time', '.', 'also'): 0.1050224953686006,
#              ('this', 'time', '.', 'also', 'there'): 0.6570606323425058,
#              ('time', '.', 'also', 'there', 'are'): 0.6570606323425058,
#              ('.', 'also', 'there', 'are', 'blankets'): 0.28393848879601136,
#              ('also', 'there', 'are', 'blankets', '('): 0.6570606323425058,
#              ('there', 'are', 'blankets', '(', 'as'): 0.6570606323425058,
#              ('are', 'blankets', '(', 'as', 'well'): 0.6570606323425058,
#              ('blankets', '(', 'as', 'well', 'as'): 0.6570606323425058,
#              ('(', 'as', 'well', 'as', 'clothes'): 0.6570606323425058,
#              ('as', 'well', 'as', 'clothes', 'and'): 0.6570606323425058,
#              ('well', 'as', 'clothes', 'and', 'shoes'): 0.6570606323425058,
#              ('as', 'clothes', 'and', 'shoes', '-'): 0.6570606323425058,
#              ('clothes', 'and', 'shoes', '-', 'women'): 0.6570606323425058,
#              ('and', 'shoes', '-', 'women', "'s"): 0.6570606323425058,
#              ('shoes', '-', 'women', "'s", 'shoes'): 0.6570606323425058,
#              ('-', 'women', "'s", 'shoes', '-'): 0.6570606323425058,
#              ('women', "'s", 'shoes', '-', 'but'): 0.6570606323425058,
#              ("'s", 'shoes', '-', 'but', 'they'): 0.6570606323425058,
#              ('shoes', '-', 'but', 'they', 'are'): 0.6570606323425058,
#              ('-', 'but', 'they', 'are', "n't"): 0.39652492505828807,
#              ('but', 'they', 'are', "n't", 'important'): 0.06886260532324838,
#              ('they', 'are', "n't", 'important', ')'): 0.6570606323425058,
#              ('are', "n't", 'important', ')', ','): 0.6570606323425058,
#              ("n't", 'important', ')', ',', 'a'): 0.6570606323425058,
#              ('important', ')', ',', 'a', 'lot'): 0.6570606323425058,
#              (')', ',', 'a', 'lot', 'of'): 0.6570606323425058,
#              (',', 'a', 'lot', 'of', 'blankets'): 0.035061405317166144,
#              ('a', 'lot', 'of', 'blankets', ','): 0.6570606323425058,
#              ('lot', 'of', 'blankets', ',', 'and'): 0.6570606323425058,
#              ('of', 'blankets', ',', 'and', 'i'): 0.6570606323425058,
#              ('blankets', ',', 'and', 'i', 'badly'): 0.6570606323425058,
#              (',', 'and', 'i', 'badly', 'needed'): 0.6570606323425058,
#              ('and', 'i', 'badly', 'needed', 'those'): 0.6570606323425058,
#              ('i', 'badly', 'needed', 'those', 'last'): 0.6570606323425058,
#              ('badly',
#               'needed',
#               'those',
#               'last',
#               'winter'): 0.6570606323425058,
#              ('needed', 'those', 'last', 'winter', 'but'): 0.6570606323425058,
#              ('those', 'last', 'winter', 'but', 'did'): 0.6570606323425058,
#              ('last', 'winter', 'but', 'did', "n't"): 0.6570606323425058,
#              ('winter', 'but', 'did', "n't", 'realize'): 0.6570606323425058,
#              ('but', 'did', "n't", 'realize', 'they'): 0.22114746702757215,
#              ('did', "n't", 'realize', 'they', 'were'): 0.6133156290440296,
#              ("n't", 'realize', 'they', 'were', 'here'): 0.22114746702757215,
#              ('realize', 'they', 'were', 'here', '.'): 0.6570606323425058,
#              ('they', 'were', 'here', '.', 'also'): 0.1329467319687954,
#              ('were', 'here', '.', 'also', 'a'): 0.6570606323425058,
#              ('here', '.', 'also', 'a', 'very'): 0.6570606323425058,
#              ('.', 'also', 'a', 'very', 'nice'): 0.6570606323425058,
#              ('also', 'a', 'very', 'nice', 'shoe'): 0.6570606323425058,
#              ('a', 'very', 'nice', 'shoe', 'rack'): 0.6570606323425058,
#              ('very', 'nice', 'shoe', 'rack', '.'): 0.6570606323425058,
#              ('nice', 'shoe', 'rack', '.', 'the'): 0.6570606323425058,
#              ('shoe', 'rack', '.', 'the', 'woman'): 0.6570606323425058,
#              ('rack', '.', 'the', 'woman', 'comes'): 0.6570606323425058,
#              ('.', 'the', 'woman', 'comes', 'back'): 0.18109874030235643,
#              ('the', 'woman', 'comes', 'back', 'to'): 0.6570606323425058,
#              ('woman', 'comes', 'back', 'to', 'say'): 0.6570606323425058,
#              ('comes', 'back', 'to', 'say', 'or'): 0.6570606323425058,
#              ('back', 'to', 'say', 'or', 'do'): 0.6570606323425058,
#              ('to', 'say', 'or', 'do', 'something'): 0.39652492505828807,
#              ('say', 'or', 'do', 'something', '.'): 0.6570606323425058,
#              ('or', 'do', 'something', '.', '['): 0.22114746702757215,
#              ('do', 'something', '.', '[', 'i'): 0.7930419197766817,
#              ('something', '.', '[', 'i', 'do'): 0.39652492505828807,
#              ('.', '[', 'i', 'do', "n't"): 0.8880230672641279,
#              ('[', 'i', 'do', "n't", 'know'): 0.7687119718491752,
#              ('i', 'do', "n't", 'know', 'what'): 0.1922356425544765,
#              ('do', "n't", 'know', 'what', ','): 0.016774746741028086,
#              ("n't", 'know', 'what', ',', 'and'): 0.3150632852900033,
#              ('know', 'what', ',', 'and', 'the'): 0.28393848879601136,
#              ('what', ',', 'and', 'the', 'dream'): 0.6570606323425058,
#              (',', 'and', 'the', 'dream', 'ended'): 0.39883487814346263,
#              ('and', 'the', 'dream', 'ended', 'about'): 0.07395525500741018,
#              ('the', 'dream', 'ended', 'about', 'there'): 0.6570606323425058,
#              ('dream', 'ended', 'about', 'there', ','): 0.6570606323425058,
#              ('ended', 'about', 'there', ',', 'i'): 0.6570606323425058,
#              ('about', 'there', ',', 'i', 'think'): 0.6570606323425058,
#              ('there', ',', 'i', 'think', '.'): 0.3865504098709183,
#              (',', 'i', 'think', '.', ']'): 0.010281718321160243,
#              ('i', 'think', '.', ']', 'me'): 0.39652492505828807,
#              ('think', '.', ']', 'me', 'pulling'): 0.6570606323425058,
#              ('.', ']', 'me', 'pulling', 'the'): 0.6570606323425058,
#              (']', 'me', 'pulling', 'the', 'green'): 0.6570606323425058,
#              ('me', 'pulling', 'the', 'green', 'leaves'): 0.6570606323425058,
#              ('pulling', 'the', 'green', 'leaves', 'and'): 0.6570606323425058,
#              ('the', 'green', 'leaves', 'and', 'berries'): 0.6570606323425058,
#              ('green', 'leaves', 'and', 'berries', 'off'): 0.6570606323425058,
#              ('leaves', 'and', 'berries', 'off', 'some'): 0.6570606323425058,
#              ('and', 'berries', 'off', 'some', 'branches'): 0.6570606323425058,
#              ('berries', 'off', 'some', 'branches', 'or'): 0.6570606323425058,
#              ('off', 'some', 'branches', 'or', 'a'): 0.6570606323425058,
#              ('some', 'branches', 'or', 'a', 'bush'): 0.6570606323425058,
#              ('branches', 'or', 'a', 'bush', '('): 0.6570606323425058,
#              ('or', 'a', 'bush', '(', 'not'): 0.6570606323425058,
#              ('a', 'bush', '(', 'not', 'from'): 0.6570606323425058,
#              ('bush', '(', 'not', 'from', 'a'): 0.6570606323425058,
#              ('(', 'not', 'from', 'a', 'live'): 0.6570606323425058,
#              ('not', 'from', 'a', 'live', 'one'): 0.6570606323425058,
#              ('from', 'a', 'live', 'one', 'growing'): 0.39652492505828807,
#              ('a', 'live', 'one', 'growing', 'in'): 0.6570606323425058,
#              ('live', 'one', 'growing', 'in', 'the'): 0.6570606323425058,
#              ('one', 'growing', 'in', 'the', 'ground'): 0.6570606323425058,
#              ('growing', 'in', 'the', 'ground', ','): 0.6570606323425058,
#              ('in', 'the', 'ground', ',', 'but'): 0.28393848879601136,
#              ('the', 'ground', ',', 'but', 'inside'): 0.0644261420593791,
#              ('ground', ',', 'but', 'inside', 'the'): 0.6570606323425058,
#              (',', 'but', 'inside', 'the', 'house'): 0.28393848879601136,
#              ('but', 'inside', 'the', 'house', ')'): 0.6570606323425058,
#              ('inside', 'the', 'house', ')', '.'): 0.6570606323425058,
#              ('the', 'house', ')', '.', 'a'): 0.1329467319687954,
#              ('house', ')', '.', 'a', 'boy'): 0.6570606323425058,
#              (')', '.', 'a', 'boy', 'of'): 0.6570606323425058,
#              ('.', 'a', 'boy', 'of', '10'): 0.39652492505828807,
#              ('a', 'boy', 'of', '10', 'or'): 0.6570606323425058,
#              ('boy', 'of', '10', 'or', '12'): 0.6570606323425058,
#              ('of', '10', 'or', '12', 'is'): 0.6570606323425058,
#              ('10', 'or', '12', 'is', 'impatiently'): 0.6570606323425058,
#              ('or', '12', 'is', 'impatiently', 'telling'): 0.6570606323425058,
#              ('12', 'is', 'impatiently', 'telling', 'me'): 0.6570606323425058,
#              ('is', 'impatiently', 'telling', 'me', ','): 0.6570606323425058,
#              ('impatiently', 'telling', 'me', ',', '``'): 0.6570606323425058,
#              ('telling', 'me', ',', '``', 'mother'): 0.1329467319687954,
#              ('me', ',', '``', 'mother', "'s"): 0.6570606323425058,
#              (',', '``', 'mother', "'s", 'asleep'): 0.6570606323425058,
#              ('``', 'mother', "'s", 'asleep', "''"): 0.6570606323425058,
#              ('mother', "'s", 'asleep', "''", '('): 0.6570606323425058,
#              ("'s", 'asleep', "''", '(', 'i'): 0.6570606323425058,
#              ('asleep', "''", '(', 'i', 'think'): 0.6570606323425058,
#              ("''", '(', 'i', 'think', ')'): 0.36219385870234483,
#              ('(', 'i', 'think', ')', '-'): 0.036335348209211846,
#              ('i', 'think', ')', '-', 'as'): 0.6570606323425058,
#              ('think', ')', '-', 'as', 'if'): 0.6570606323425058,
#              (')', '-', 'as', 'if', 'i'): 0.6570606323425058,
#              ('-', 'as', 'if', 'i', "'m"): 0.6570606323425058,
#              ('as', 'if', 'i', "'m", 'not'): 0.0974575527873556,
#              ('if', 'i', "'m", 'not', 'supposed'): 0.06052671716914943,
#              ('i', "'m", 'not', 'supposed', 'to'): 0.9503951735228037,
#              ("'m", 'not', 'supposed', 'to', 'be'): 0.4751985371546745,
#              ('not', 'supposed', 'to', 'be', 'doing'): 0.1461858418981423,
#              ('supposed', 'to', 'be', 'doing', 'what'): 0.03276395093893053,
#              ('to', 'be', 'doing', 'what', 'i'): 0.7930419197766817,
#              ('be', 'doing', 'what', 'i', "'m"): 0.39652492505828807,
#              ('doing', 'what', 'i', "'m", 'doing'): 0.7930419197766817,
#              ('what', 'i', "'m", 'doing', 'instead'): 0.015262363946377673,
#              ('i', "'m", 'doing', 'instead', 'of'): 0.6570606323425058,
#              ("'m", 'doing', 'instead', 'of', 'her'): 0.6570606323425058,
#              ('doing', 'instead', 'of', 'her', 'or'): 0.6570606323425058,
#              ('instead', 'of', 'her', 'or', 'without'): 0.6570606323425058,
#              ('of', 'her', 'or', 'without', 'her'): 0.6570606323425058,
#              ('her', 'or', 'without', 'her', 'knowledge'): 0.6570606323425058,
#              ('or', 'without', 'her', 'knowledge', 'or'): 0.6570606323425058,
#              ('without',
#               'her',
#               'knowledge',
#               'or',
#               'something'): 0.6570606323425058,
#              ('her', 'knowledge', 'or', 'something', '.'): 0.6570606323425058,
#              ('knowledge', 'or', 'something', '.', 'this'): 0.6570606323425058,
#              ('or', 'something', '.', 'this', 'is'): 0.19327584918399482,
#              ('something', '.', 'this', 'is', 'in'): 0.22114746702757215,
#              ('.', 'this', 'is', 'in', 'an'): 0.1329467319687954,
#              ('this', 'is', 'in', 'an', 'old'): 0.6570606323425058,
#              ('is', 'in', 'an', 'old', 'rambling'): 0.28393848879601136,
#              ('in', 'an', 'old', 'rambling', 'house'): 0.6570606323425058,
#              ('an', 'old', 'rambling', 'house', 'with'): 0.6570606323425058,
#              ('old', 'rambling', 'house', 'with', 'lots'): 0.6570606323425058,
#              ('rambling', 'house', 'with', 'lots', 'of'): 0.6570606323425058,
#              ('house', 'with', 'lots', 'of', 'old'): 0.19008055533379714,
#              ('with', 'lots', 'of', 'old', 'furniture'): 0.28393848879601136,
#              ('lots', 'of', 'old', 'furniture', 'and'): 0.39652492505828807,
#              ('of',
#               'old',
#               'furniture',
#               'and',
#               'interconnected'): 0.39652492505828807,
#              ('old',
#               'furniture',
#               'and',
#               'interconnected',
#               'rooms'): 0.6570606323425058,
#              ('furniture',
#               'and',
#               'interconnected',
#               'rooms',
#               '.'): 0.6570606323425058,
#              ('and',
#               'interconnected',
#               'rooms',
#               '.',
#               'lace'): 0.6570606323425058,
#              ('interconnected',
#               'rooms',
#               '.',
#               'lace',
#               'doilies'): 0.6570606323425058,
#              ('rooms', '.', 'lace', 'doilies', 'on'): 0.6570606323425058,
#              ('.', 'lace', 'doilies', 'on', 'little'): 0.6570606323425058,
#              ('lace', 'doilies', 'on', 'little', 'tables'): 0.6570606323425058,
#              ('doilies', 'on', 'little', 'tables', ','): 0.6570606323425058,
#              ('on', 'little', 'tables', ',', 'throw'): 0.6570606323425058,
#              ('little', 'tables', ',', 'throw', 'rugs'): 0.6570606323425058,
#              ('tables', ',', 'throw', 'rugs', ','): 0.6570606323425058,
#              (',', 'throw', 'rugs', ',', 'etc'): 0.6570606323425058,
#              ('throw', 'rugs', ',', 'etc', '.'): 0.6570606323425058,
#              ('rugs', ',', 'etc', '.', 'some'): 0.6570606323425058,
#              (',', 'etc', '.', 'some', 'of'): 0.44229051119426094,
#              ('etc', '.', 'some', 'of', '``'): 0.39652492505828807,
#              ('.', 'some', 'of', '``', 'us'): 0.6570606323425058,
#              ('some', 'of', '``', 'us', "''"): 0.6570606323425058,
#              ...})

# %% [markdown]
# ## Evaluate perplexity

# %%
def calculate_perplexity(test_tokens, ngram_probabilities, n):
    """Calculates the perplexity of a test corpus given n-gram probabilities."""
    log_probability_sum = 0
    ngram_count = 0
    
    for i in range(len(test_tokens)-n+1):
        ngram = tuple(test_tokens[i:i+n])
        log_probability_sum += math.log2(ngram_probabilities[ngram])
        ngram_count += 1
    
    average_log_probability = -log_probability_sum / ngram_count
    perplexity = math.pow(2, average_log_probability)
    
    return perplexity

# %%
calculate_perplexity(train_tokens, ngram_probabilities, n)
# Out:
# 2.4339180118336756

# %%
calculate_perplexity(test_tokens, ngram_probabilities, n)
# Out:
# 17168.83336216221

# %%
def greedy_sampling(context, vocab, ngram_probabilities, n, max_length = 50):
    
    sentence = []

    if len(context) < (n-1):
        print("len(context) < n")
        return sentence

    context = context[-(n-1):]
    
    for i in range(max_length):

        probs = dict()
        
        for v in vocab:

            ngram = list(context)
            ngram.append(v)
            ngram = tuple(ngram)
            probs[v] = ngram_probabilities[ngram]

        best_token = max(probs, key=probs.get) # greedy 
        #print(best_v)
        #print(probs[best_v])
        
        if probs[best_token] == 0:
            print("prob = 0")
            return sentence
            
        sentence.append(best_token)
        context = list(context)[1:]
        context.append(best_token)
        context = tuple(context)
            
    return sentence

# %%
context = ['i', "'m", 'in', 'honduras']
context = ['the', 'one', 'at', 'the']
sentence = greedy_sampling(context, vocab, ngram_probabilities, n, max_length = 200)
print(" ".join(context) + " " +  " ".join(sentence))
# Out:
# the one at the meads 's house , where i was going . i was walking down the street and i was on the phone . i am constantly interrupted by the antics of his 2-year-old boy who i am apparently babysitting . the boy runs and jumps from a high place . i yell , `` get him in the car ! i 'll be right back . '' i said , `` i 'm going to be late for work and i ca n't remember what it was . i was in a room with my friends niles zelling , matt yams , queen billman , and another woman . i am in a house . i was in a room with my friends niles zelling , matt yams , queen billman , and another woman . i am in a house . i was in a room with my friends niles zelling , matt yams , queen billman , and another woman . i am in a house . i was in a room with my friends niles zelling , matt yams , queen billman , and another woman . i am in a house . i was in a room

# %%
train_strings[:250]
# Out:
# "the one at the meads's house, where it's bigger inside than out; there's a european village just inside, with a cobblestone street and a pied-piper sort of man with curly hair, he can do things like juggle - i go up the back stairs [there aren't any "

# %% [markdown]
# ## TODO
#
# padding, backoff, interpolation, better sampling methods (top-k, top-p), etc.

# %%
def padding(sequence, n, pad_left=False, pad_right=False, left_pad_symbol=None, right_pad_symbol=None):
    if pad_left:
        sequence = [left_pad_symbol] * (n-1) + sequence
    if pad_right:
        sequence += [right_pad_symbol] * (n-1)
    return sequence

# %% [markdown]
# # Using NLTK.lm

# %% [markdown]
# ## Import dataset and prepare training and test sets

# %%
from nltk.lm.preprocessing import padded_everygram_pipeline
from nltk.lm import MLE, StupidBackoff, Laplace

# %%
train_sents = sent_tokenize(train_strings)
print(len(train_sents))
train_sents_tokens = [word_tokenize(s) for s in train_sents]

test_sents = sent_tokenize(test_strings)
print(len(test_sents))
test_sents_tokens = [word_tokenize(s) for s in test_sents]
# Out:
# 351146
# 5627

# %%
test_sents_tokens[:2]
# Out:
# [['i',
#   "'m",
#   'in',
#   'honduras',
#   'at',
#   'some',
#   'kind',
#   'of',
#   'border',
#   'crossing',
#   '.'],
#  ['a',
#   'wide',
#   'corridor',
#   'of',
#   'thick',
#   'fenced',
#   'scrub',
#   'is',
#   'off',
#   'on',
#   'either',
#   'side',
#   '..',
#   'everything',
#   'is',
#   'grim',
#   ',',
#   'sinister',
#   ',',
#   'ominous',
#   '.']]

# %%
n = 3

train, vocab = padded_everygram_pipeline(n, train_sents_tokens)

#lm = MLE(n) # Maximum Likelihood Estimate
#lm = StupidBackoff(order = n) # Stupid Backoff
lm = Laplace(n) # Laplace smoothing

# %%
lm.fit(train, vocab)
print(lm.vocab)
print(len(lm.vocab))
# Out:
# <Vocabulary with cutoff=1 unk_label='<UNK>' and 52182 items>
# 52182

# %%
lm.vocab.lookup(["france", "gustave"])
# Out:
# ('france', '<UNK>')

# %%
print(lm.counts)
# Out:
# <NgramCounter with 3 ngram orders and 19774470 ngrams>

# %%
lm.counts['gustave']
# Out:
# 0

# %%
lm.counts['france']
# Out:
# 62

# %%
lm.counts['dream']
# Out:
# 7106

# %%
lm.counts[['i']]['love']
# Out:
# 288

# %%
lm.counts[['i']]['want']
# Out:
# 1624

# %%
lm.score("i")
# Out:
# 0.038742394727067954

# %%
lm.score("france")
# Out:
# 9.006667507288967e-06

# %%
lm.score("gustave")
# Out:
# 1.429629763061741e-07

# %%
lm.score("i", ["love"])
# Out:
# 7.431076763022962e-05

# %%
lm.perplexity(train_sents_tokens)
# Out:
# 50465.94290553111

# %%
lm.perplexity(test_sents_tokens)
# Out:
# 49653.97430774097

# %%
lm.generate(20, random_seed=42)
# Out:
# ['land',
#  ')',
#  'blue',
#  ',',
#  'showing',
#  'my',
#  'stamina',
#  '.',
#  '</s>',
#  '</s>',
#  '</s>',
#  '</s>',
#  '</s>',
#  '</s>',
#  '</s>',
#  '</s>',
#  '</s>',
#  '</s>',
#  '</s>',
#  '</s>']

# %%
lm.generate(20, text_seed=['i'], random_seed=42)
# Out:
# ['say',
#  ',',
#  '``',
#  'hon',
#  ',',
#  'relax',
#  '.',
#  "''",
#  '</s>',
#  '</s>',
#  '</s>',
#  '</s>',
#  '</s>',
#  '</s>',
#  '</s>',
#  '</s>',
#  '</s>',
#  '</s>',
#  '</s>',
#  '</s>']
